# %%
#https://stackoverflow.com/questions/45501082/set-google-application-credentials-in-python-project-to-use-google-api
# !pip install searchtweets
from google.cloud import language_v1
from google.cloud.language_v1 import enums
from google.colab import drive
drive.mount('/content/drive')
import os
import six
import pandas as pd

os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/drive/My Drive/Files/winter-cocoa-276802-380f683a2113.json"
# Out:
# Collecting searchtweets
#   Downloading https://files.pythonhosted.org/packages/5b/36/0eb49d46fa66f0bccb2f90c8ad899ae7678d25a7527832bce1f176121e1e/searchtweets-1.7.5-py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from searchtweets) (2.23.0)
# Collecting tweet-parser
#   Downloading https://files.pythonhosted.org/packages/4b/ea/cb82efb43dbcb115ea447313fbd287ff66349b34bdfdb4a78e25d3a42cb0/tweet_parser-1.13.2-py3-none-any.whl
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from searchtweets) (3.13)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->searchtweets) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->searchtweets) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->searchtweets) (2020.4.5.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->searchtweets) (3.0.4)
# Installing collected packages: tweet-parser, searchtweets
# Successfully installed searchtweets-1.7.5 tweet-parser-1.13.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from searchtweets import  gen_rule_payload, load_credentials,collect_results

premium_search_args = load_credentials(r"/content/drive/My Drive/Files/twitter_keys.yaml", account_type="premium")

hash_one = 'to:tmobile service -@TMobileHelp -@TMobileBusiness -@TMobileNews \
-@Starbucks -@JohnLegere -@MetroByTMobile -@TMobilePark \
-tv -home -install -channels -FB -DVR \
-@googlefi -@xfinitymobile -@Walgreens\
-directv -directtv -@directtv -stream -streaming \
-@firstnet -xfinity -carriers -sprint \
-@sprint -@att -@verizon -comcast \
-metro -@comcast -@FilmStruck \
-wifi -wi-fi -cable -modem -internet -dsl -fiber -router -broadband \
-iphone -Galaxy -S8 -S9 -(NOTE 10) -Samsung -Motorola -Android \
-commercial -commercials -promo -@BurgerKing -@xbox -@SamsungMobileUS -@tacobell \
-@nfl -NFL -nfl -nba -NBA -@mlb -playoffs -CBS -CNN -Trump \
-@nature_org -advertising -(fox news) -fox -@iHeartRadio -@LiveNation -@deadpoolmovie \
-@STARZ -HBO -hbomax -@hbomax -@hbo -@XMenMovies -@bookingcom -@dunkindonuts \
-@foxsoccer -@foxtv -@foxnews -@TNTdrama -@netflix \
-@kingjames -@jonasbrothers -@PostMalone -@OnePlus_USA -@costco -@ArianaGrande \
lang:en \
-is:retweet -is:verified -has:images -has:media -has:videos -has:links -has:hashtags'

#Taken out for 2014
#-bill -payment

'''
has:profile_geo
-at&t -@attjobs -@lifeatatt -@ItsOnATT -@ATTimpact -@ATTBusiness -@directvnow \
-@ATTSmallBiz -@ATTDirectv -@ATTHelloLab -@atthelp -@attcares -@ATTCustServ -@ATTTHANKS \
-@attsmallbusines -@ATTBusinessCare -@LenaWaithe -@socialworks -LGBTQ -@TrevorProject
-uverse -@uverse -u-verse -(Puerto Rico) -mbps

-@SamsungMobileUS
-@adultswim -@LOVELOUDfest -@Showtime
-@NETGEAR -@BleacherReport -@youtube
-sponsored -sponsor -Asus -Moto -@TIFF_NET -@WNBA -sponsoring @ATTmobilitycare
AT&amp;T -political -congress -@GOP -GOP -@realDonaldTrump
-@AsurionCares -@metropcs -@directvnow -@DIRECTVNowHelp 
-Internet -routers -@attnewengland -(John Oliver) -discrimination -gigabit
-@xfinity -@boostmobile -WiFi -Wi-Fi -@attstadium
-climate -(clean energy) -@greenamerica -@sesamestreet -(sesame street) 
-@fifaworldcup -FIFA -fifa -@att -@apple -@DodgersStadium
-@Windows -@foxandfriends -Fox -@IvankaTrump -Ivanka 
-@fullfrontalsamb -@flickr  -@AppleMusic -@lollapalooza  \
-@maroon5 -@nintendoamerica -@jtimberlake -@jetblue 
-(Samantha Bee)-@iamsambee -(SAMANTHA BEE) -(Sam B OR SAM B)
-@vzwsupport -@verizonsupport -@verizonfios -@vzenterprise \
-(Verizon Center) -Fios -fios \
-verizonup
'''

rule = gen_rule_payload(hash_one, results_per_call=500, from_date="2011-01-01", to_date="2012-02-07") 

print(rule)

tweets = collect_results(rule, 
                         max_results=500, #Change to 500 after TESTING
                         result_stream_args=premium_search_args)

#[print(tweet.all_text) for tweet in tweets[0:10]]

#type(tweets)
print(len(tweets))
df = pd.DataFrame(tweets)
list(df)
# Out:
# Grabbing bearer token from OAUTH
# {"query": "to:tmobile service -@TMobileHelp -@TMobileBusiness -@TMobileNews -@Starbucks -@JohnLegere -@MetroByTMobile -@TMobilePark -tv -home -install -channels -FB -DVR -@googlefi -@xfinitymobile -@Walgreens-directv -directtv -@directtv -stream -streaming -@firstnet -xfinity -carriers -sprint -@sprint -@att -@verizon -comcast -metro -@comcast -@FilmStruck -wifi -wi-fi -cable -modem -internet -dsl -fiber -router -broadband -iphone -Galaxy -S8 -S9 -(NOTE 10) -Samsung -Motorola -Android -commercial -commercials -promo -@BurgerKing -@xbox -@SamsungMobileUS -@tacobell -@nfl -NFL -nfl -nba -NBA -@mlb -playoffs -CBS -CNN -Trump -@nature_org -advertising -(fox news) -fox -@iHeartRadio -@LiveNation -@deadpoolmovie -@STARZ -HBO -hbomax -@hbomax -@hbo -@XMenMovies -@bookingcom -@dunkindonuts -@foxsoccer -@foxtv -@foxnews -@TNTdrama -@netflix -@kingjames -@jonasbrothers -@PostMalone -@OnePlus_USA -@costco -@ArianaGrande lang:en -is:retweet -is:verified -has:images -has:media -has:videos -has:links -has:hashtags", "maxResults": 500, "toDate": "201202070000", "fromDate": "201101010000"}
# 500
# ['created_at',
#  'id',
#  'id_str',
#  'text',
#  'source',
#  'truncated',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'is_quote_status',
#  'quote_count',
#  'reply_count',
#  'retweet_count',
#  'favorite_count',
#  'entities',
#  'favorited',
#  'retweeted',
#  'filter_level',
#  'lang',
#  'matching_rules']

# %%
#Change the order of the columns
df = df[['created_at',
 'text',
 'truncated',
 'source',
 'id',
 'id_str',
 'in_reply_to_status_id',
 'in_reply_to_status_id_str',
 'in_reply_to_user_id',
 'in_reply_to_user_id_str',
 'in_reply_to_screen_name',
 'user',
 'geo',
 'coordinates',
 'place',
 'contributors',
 'is_quote_status',
 'quote_count',
 'reply_count',
 'retweet_count',
 'favorite_count',
 'entities',
 'favorited',
 'retweeted',
 'filter_level',
 'lang',
 'matching_rules']]

#2014 -The following are not in the index for 2014: # 'extended_tweet','display_text_range',

# %%
file_name = r'/content/drive/My Drive/Files/raw_files/tmobile/tmobile-test-2011-2-Feb09-raw.csv'
df.to_csv(file_name, sep=',', encoding='utf-8')
